# %%
import tweepy
import csv
from textblob import TextBlob

# Step 1 - Authenticate
consumer_key= 'QRhXMskrw3dodQvPGj8fyu1Ha'
consumer_secret= 'J0VxZ9NDT3jQMsj5IRxz7RgxIhbd38z2vksFK3mSn4Vf9tJCZw'

access_token='488175306-KMoY1qZn1ldO5UEGApvPSzcgNX4TYV8fk11CIKM7'
access_token_secret='mi00kZHJaQjkKEhtLUpuezg6zng99wx2haShrobEcnKyM'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

subject = 'DOTA2'
public_tweets = api.search(subject, count = 100)



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself

tweets = open(subject+'.csv', 'w', encoding = "utf-8")
writer = csv.writer(tweets)

#saves tweets to a CSV
for tweet in public_tweets:
    writer.writerow([tweet.text])
    print(tweet.text)
    
    
    # Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    if analysis.sentiment[0] > .3:
        writer.writerow(['Positive'])
        print('Positive')
    if analysis.sentiment[0] < -.3:
        writer.writerow(['Negitive'])
        print('Negitive')
    print(analysis.sentiment)
# Out:
# RT @redditdota2: Boy with that haircut has 100% chance to buy battlefury on every carry https://t.co/sLxjULWBtN #dota2 https://t.co/10fgOX9…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Is there a list of English Twitch casters who will be casting ESL Genting 2018 - I'm not watching on Facebook https://t.co/tBxuJhoa36
# Sentiment(polarity=0.0, subjectivity=0.0)
# "The Potato Sack" was a collection of indie games released on Steam in 2011 as a promotion for which game?
# 🇦… https://t.co/5JbzngmEQn
# Sentiment(polarity=-0.2, subjectivity=0.2)
# RT @team_glb: What a game to start the week with 😍 Our @DOTA2 heroes pull ahead in the StarLadder Dota2 Tournament. Shout-out to the boys f…
# Negitive
# Sentiment(polarity=-0.4, subjectivity=0.4)
# What a game to start the week with 😍 Our @DOTA2 heroes pull ahead in the StarLadder Dota2 Tournament. Shout-out to… https://t.co/zduc9J2SaN
# Negitive
# Sentiment(polarity=-0.4, subjectivity=0.4)
# ...
